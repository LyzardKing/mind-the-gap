# %% [markdown]
# # Test breakdown generator

# %%
PROMPT_JSON_EXTRACTION = """
# Prompt: Transform Legal Text into structured JSON representation

## Objective

Convert the provided legal text into structured JSON representation structure following the step by step below.

## Step by Step

1. Break the paragraph down into **individual sentences** and convert them to the **singular tense**.
    - Every subject, verb and complement must be converted into *singular tense**.

2. For each sentence do the following relevant information:
    - Subject: Entity (vehicle, person, etc.) that performs the action described in the conclusion.
    - Conclusion: The action that is present in the main sentence.
    - Deontic Modality: Optional. The importance of the action indicated in the conclusion. Either, should/should not or must/must not, can/can not.
    - Conditions: Things that have to be true, in order to the conclusion to be applicable.
    - Syntactic structure: Sub-divide both conclusion and conditions in: subject, deontic modality (for conclusion only), action (verb), and complement (place, object, etc.). If conclusion or conditions are **None**, syntactic structure must be empty.

3. Present the JSON with the extracted elements for each sentence.

The JSON must have the following structure.
- Every sentence will become a JSON object.
- Every subject and verb and complement must be converted into *singular tense**
- Each JSON object will have the "source_text" and the "syntactic_structure".
- The "source_text" is the original sentence.
- "syntactic_structure" contains the structure syntatic information for both conclusions and conditions, if any. That is, "subject", "deontic", "verb" and "complement".
- If the subject is "you" replace by "vehicle".
- If the verb relates to intent, such as "wants", "will", "intends", replace it with "intends".
- If there is no explicit deontic operator, assume "can" if applicable.
- Convert everything to **singular tense**.

Example:
```json
[
    {
        "source_text": "[Original sentence]",
        "syntactic_structure": {
            "conclusion": {
                "subject": "[Subject, if any, or null]",
                "deontic": "[Deontic operator, if any, or null]",
                "verb": "[Verb, if any, or null]",
                "object": "[Object, if any, or null]",
            },
            "conditions": [
                {
                    "subject": "[Subject, if any, or null]",
                    "verb": "[Verb, if any, or null]",
                    "object": "[Object, if any, or null]",
                }
                [More conditions if any...]
            ]
        }
    },
]
```


## How to find conclusions and conditions

### Conclusions

Follow bellow some details on how to extract the conclusions.

- *Predicate name* is the deontic modality if it exists (must, should, etc.). If not assume "can".
- Arguments are the subject, action and complements (if they exist). A complement can be a location, a time, a characteristic.

### Conditions

Follow bellow some details on how to extract the conditions.

- Find the subject, the verb, and the complement.
- Use the verb as the predicate name.
- The arguments are the subject and complements.
- USE **singular** to write subject, verb, and complement.


## Few Shot examples

### Example 1:

**Text:** You MUST stop behind the line at a junction with a 'Stop' sign and a solid white line across the road. Wait for a safe gap in the traffic before you move off.

**## Break the paragraph down into **individual sentences** and convert them to the singular tense**

1. You MUST stop behind the line at a junction with a 'Stop' sign and a solid white line across the road.
2. Wait for a safe gap in the traffic before you move off.

**Step 2: For each phrase, extract the relevant information**

1. You MUST stop behind the line at a junction with a 'Stop' sign and a solid white line across the road.

- Subject: "vehicle"
- Conclusion: "stop behind the line at a junction"
- Deontic modality: "must"
- Conditions:
    * Singular: "the junction has a 'Stop' sign"
    * Singular: "the junction has a solid white line across the road"
- Syntactic structure (Singular tense):
    Conclusion:
        * Subject: "vehicle", Deontic: "must", Verb: "stop", Complement: "behind the line at a junction"
    Conditions:
        * Subject: "junction", Verb: "has", Complement: "a 'Stop' sign"
        * Subject: "junction", Verb: "has", Complement: "a solid white line across the road"


2. Wait for a safe gap in the traffic before you move off.

- Subject: "vehicle"
- Conclusion: "move off"
- Deontic modality: None
- Conditions:
    * Singular: "there is a safe gap in the traffic"

- Syntactic structure (Singular tense):
    Conclusion:
        * Subject: "vehicle", Deontic: "can", Verb: "move off", Complement: "behind the line at a junction"
    Conditions:
        * Subject: "a safe gap", Verb: "is", Complement: "in the traffic"


**Step 3: Present the JSON**

```json
[
    {
        "source_text": "You MUST stop behind the line at a junction with a 'Stop' sign and a solid white line across the road.",
        "syntactic_structure": {
            "conclusion": {
                "subject": "vehicle",
                "deontic": "must",
                "verb": "stop",
                "complement": "behind the line at a junction",
            }
            "conditions":[
                {
                    "subject": "junction",
                    "verb": "has",
                    "complement": "a 'Stop' sign",
                },
                {
                    "subject": "junction",
                    "verb": "has",
                    "complement": "a solid white line across the road",
                },
            ]
        }
    },
    {
        "source_text": "Wait for a safe gap in the traffic before you move off.",
        "syntactic_structure": {
            "conclusion": {
                "subject": "vehicle",
                "deontic": "None",
                "verb": "move off",
                "complement": "",
            }
            "conditions":[
                {
                    "subject": "a safe gap",
                    "verb": "is",
                    "complement": "in the traffic",
                }
            ]
        }
    }
]
```

## Final remarks

- Extract the sentences and re-write them into the **singular tense**
- Replace subject "you" with "vehicle"
- Extract the JSON structure specificed.


""".strip()

PROMPT_GENERATOR = """
# Prompt: Transform Legal Text and JSON structure into Logical English (LE)

## Objective

Convert the provided legal text considering the JSON structure into Logical English (LE) following the step by step below.


- For each JSON object with conclusion and conditions, *identify the templates*. And explain using comment ("%") why you chose the templates.


**Conclusion**

- You should explicitly choose *one* of the following templates to write the conclusion.

```le
the templates are:
*an agent* should *an action*.
*an agent* must *an action*.
*an agent* can *an action*.
*an agent* must *an action* to *an agent*.
*an agent* must *an action* at *a location*.
*an agent* should *an action* to *an agent*.
*an agent* sees *an item*.
*an agent* is at *a place*.
*an agent* is in *a place*.
*an agent* _is *a place*.
*an agent* cannot *an action*.
```

- Only create a new template, if and only if, the existing templates *do not fit*.
- Each template has a syntax and an intent. You must check both before choosing a template.
- Present the conclusion together with the corresponding template. For example:
    * "you must stop behind the line at a junction": *an agent* must *an action* at *a location*.

**Conditions**

Follow bellow some details on how to extract the conditions.

- Find the subject, the verb, and the specification.
- Use the verb as the predicate name.
- The arguments are the subject and specifications.
- You should explicitly choose *one* of the following templates to write the conditions.

```le
the templates are

*a thing* has *a thing*
*a thing* is *a thing*
*a thing* exists in *a thing*
```

- Only create a new template, if and only if, the existing templates *do not fit*.
- For each condition, present it together with the corresponding template.

For example:
"The junction has stop sign": *a thing* has *a property*.

The output for this step should be like:
**Conditions:**
    - "Condition 1": `Associated template`
    - "Condition 2": `Another associated template`
    - ...
**Conclusion:**
    - "Conclusion": `Associated template`

Now let's go back to the step-by-step:

5. *Build the rules* using the identified templates.

- Connect the rules and conditions using the templates and logical connections from Logical English.
- If the subject is "you", replace the agent in the templates with the constant *vehicle*.
- The ouput will be a single `le` code space delimited by triple ticks.
""".strip()

# %%
user_prompt_json = """
## Sentence to analyse

"@SOURCE_TEXT"

""".strip()

user_prompt_generator = """
## Sentence to analyse

"@SOURCE_TEXT"

## JSON Object

````json
@JSON_OBJECT
```

## Previous templates

````le
@PREVIOUS_TEMPLATES
```

""".strip()

# %%
from pipeline.rule_generation import process_existing_le
import re
import logging
from dotenv import load_dotenv

rules_to_ignore = [
]
load_dotenv()

markdown_dataset = open("../Using the road (159 to 203).md").read().strip()

existing_logical_english = open("../highway_code.le").read().strip()
existing_templates, existing_kb = process_existing_le(existing_logical_english)

existing_le = "\n\n".join([existing_templates, existing_kb])
logging.info(f"-----\n{existing_templates}\n=====\n{existing_kb}")
# Out:
# 2025-07-11 15:05:03,101 - INFO - Logging setup complete.
# 2025-07-11 15:05:03,105 - INFO - -----
# the templates are:
# *an agent* should *an action*.
# *an agent* must *an action*.
# *an agent* can *an action*.
# *an agent* must *an action* to *an agent*.
# *an agent* should *an action* to *an agent*.
# *an agent* sees *an item*.
# *an agent* is at *a place*.
# *an agent* is in *a place*.
# *an agent* _is *a place*.
# *an agent* cannot *an action*.
# =====
# the knowledge base highway_code includes:
#
# a vehicle must an action
# if the vehicle must the action to an agent.
# a vehicle should an action
# if the vehicle should the action to an agent.
#
# % Rule 170
# % [...] give way to pedestrians crossing or waiting to cross a road into which or from which you are turning.
# % If they have started to cross they have priority, so give way (see Rule H2)
# a vehicle should give way to a pedestrian
# if the vehicle is at a junction
# and the pedestrian _is crossing
#     or the pedestrian _is waiting to cross.
#
# % Rule 171
# % You MUST stop behind the line at a junction with a ‘Stop’ sign and a solid white line across the road.
# % Wait for a safe gap in the traffic before you move off.
# a vehicle must stop behind the line at a junction
# if the vehicle is at the junction
# and the vehicle sees stop sign
# and the vehicle sees solid white line across the road.
#
# % Rule 172
# % The approach to a junction may have a ‘Give Way’ sign or a triangle marked on the road.
# % You MUST give way to traffic on the main road when emerging from a junction with broken white lines across the road.
# a vehicle must give way to traffic
# if the vehicle sees give way sign
#     or the vehicle sees triangle marked on the road
#     or the vehicle sees broken white lines across the road
# and the vehicle sees traffic oncoming.
#
# % Rule 175
# % You MUST stop behind the white ‘Stop’ line across your side of the road unless the light is green.
# % If the amber light appears you may go on only if you have already crossed the stop line
# % or are so close to it that to stop might cause a collision.
# % a vehicle must stop behind the line at a junction
# % if the vehicle sees red light.
# % -
# % Rule 175 Part I
# a vehicle can enter a junction
# if the vehicle sees stop line
# and the vehicle sees green light.
#
# % Rule 175 Part II
# a vehicle can enter a junction
# if the vehicle sees stop line
# and the vehicle sees amber light
# and the vehicle is in the junction
#     or the vehicle cannot stop safely.

# %%
from pipeline.rule_generation import parse_markdown_rules

parsed_source_text = parse_markdown_rules(markdown_dataset)
junction_rules = parsed_source_text["Road junctions (rules 170 to 183)"]

# %%
from together import Together


def api_call(system_prompt=None, user_prompt="", options=None):
    if options is None:
        options = {}

    # Initialize client
    client = Together()

    # Build message list
    messages = []
    if system_prompt:
        messages.append({"role": "system", "content": system_prompt})
    messages.append({"role": "user", "content": user_prompt})

    try:
        # Send API call with dynamic options
        response = client.chat.completions.create(
            model=options.get("model", "meta-llama/Llama-3.3-70B-Instruct-Turbo-Free"),
            messages=messages,
            **{k: v for k, v in options.items() if k != "model"}  # Pass all other options
        )
        return response.choices[0].message.content
    except Exception as e:
        return f"Error: {str(e)}"

import json
import re

def extract_json_from_markdown(markdown_text: str) -> dict | None:
    """
    Parses a JSON object from a Markdown code block.

    Args:
        markdown_text: A string containing the Markdown output from an LLM.

    Returns:
        A dictionary parsed from the first JSON code block found,
        or None if no valid JSON block is found.
    """
    # This regex pattern finds a JSON code block and captures its content.
    # It handles potential leading/trailing whitespaces and newlines.
    pattern = r"```json\s*\n(.*?)\n\s*```"

    # re.DOTALL makes '.' match any character, including newlines.
    match = re.search(pattern, markdown_text, re.DOTALL)

    if match:
        json_string = match.group(1).strip()
        try:
            return json.loads(json_string)
        except json.JSONDecodeError as e:
            logging.error(f"Error decoding JSON: {e}")
            return None

    return None


from typing import List, Dict, Any

def filter_content(data: List[Dict[str, Any]]) -> List[Dict[str, Any]]:
    """
    Filters a list of objects and cleans their 'conditions' list.

    An object is kept if its 'conclusion' is valid. Within each kept object,
    any 'condition' that does not have both a subject and a verb is removed.

    Args:
        data: A list of dictionary objects to be filtered and cleaned.

    Returns:
        A new list containing the valid objects with cleaned condition lists.
    """
    filtered_list = []

    for item in data:
        # Use deepcopy to avoid modifying the original input list
        item_copy = json.loads(json.dumps(item))
        structure = item_copy.get("syntactic_structure")

        if not structure:
            continue

        # 1. Validate the 'conclusion'
        conclusion = structure.get("conclusion")
        if not conclusion:
            continue

        is_conclusion_valid = all([
            conclusion.get("subject") == "vehicle",
            conclusion.get("deontic"),
            conclusion.get("verb"),
            conclusion.get("verb") != "watch out"
        ])

        if not is_conclusion_valid:
            continue

        # 2. Clean the 'conditions' list
        original_conditions = structure.get("conditions", [])
        if original_conditions:
            valid_conditions = []
            for condition in original_conditions:
                # A condition is valid only if both 'subject' and 'verb' are present and not empty
                if condition.get("subject") and condition.get("verb"):
                    valid_conditions.append(condition)

            # Replace the old conditions list with the cleaned one
            structure["conditions"] = valid_conditions

        # 3. If the conclusion was valid, add the cleaned item to the result
        filtered_list.append(item_copy)

    return filtered_list


def extract_json_le(source_text, previous_le):
    global user_prompt_generator, user_prompt_json, PROMPT_JSON_EXTRACTION

    filled_user_prompt_json = str(user_prompt_json)
    filled_user_prompt_json = filled_user_prompt_json.replace("@SOURCE_TEXT", source_text)
    # filled_user_prompt = filled_user_prompt.replace("@PREVIOUS_TEMPLATES", previous_le)

    json_structure = None
    while not json_structure:

        response = api_call(
            system_prompt=PROMPT_JSON_EXTRACTION,
            user_prompt=filled_user_prompt_json,
            options={
                "model": "meta-llama/Llama-3.3-70B-Instruct-Turbo-Free",
                "temperature": 0.6,
                "max_tokens": 6000
            }
        )
        logging.info(f"Response: \n\n====\n{response}\n=======")

        json_structure = extract_json_from_markdown(response)

        valid_json_content = filter_content(json_structure)

        logging.info(f"Validated output: \n\n====\n{json.dumps(valid_json_content, indent=3)}\n=======")

# %%
for rule, source_text in junction_rules.items():
    if len(source_text.strip()) == 0 or rule.strip() in rules_to_ignore:
        continue

    logging.info("-" * 50)
    logging.info(f"Processing: {rule}")
    logging.info(f"Source text: \n\"{source_text}\"")
    logging.info("-" * 50)

    content = extract_json_le(
        source_text=source_text,
        previous_le=existing_logical_english
    )

    #input("\n\nPress a key to continue...")
# Out:
# 2025-07-11 15:05:03,228 - INFO - --------------------------------------------------
# 2025-07-11 15:05:03,229 - INFO - Processing: Rule 170
# 2025-07-11 15:05:03,230 - INFO - Source text:
# "Take extra care at junctions. You should
#
# *   watch out for cyclists, motorcyclists and pedestrians including powered wheelchairs/mobility scooter users as they are not always easy to see. Be aware that they may not have seen or heard you if you are approaching from behind
# *   give way to pedestrians crossing or waiting to cross a road into which or from which you are turning. If they have started to cross they have priority, so give way (see [Rule H2](/guidance/the-highway-code/introduction#ruleh2))
# *   remain behind cyclists, horse riders, horse drawn vehicles and motorcyclists at junctions even if they are waiting to turn and are positioned close to the kerb
# *   watch out for long vehicles which may be turning at a junction ahead; they may have to use the whole width of the road to make the turn (see [Rule 221](/guidance/the-highway-code/road-users-requiring-extra-care-204-to-225#rule221))
# *   watch out for horse riders who may take a different line on the road from that which you would expect
# *   not assume, when waiting at a junction, that a vehicle coming from the right and signalling left will actually turn. Wait and make sure
# *   look all around before emerging. Do not cross or join a road until there is a gap large enough for you to do so safely."
# 2025-07-11 15:05:03,231 - INFO - --------------------------------------------------
# 2025-07-11 15:05:46,014 - INFO - Response:
#
# ====
# ## Step 1: Break down the paragraph into individual sentences and convert them to singular tense
#
# 1. Take extra care at junctions.
# 2. Watch out for cyclists, motorcyclists, and pedestrians, including powered wheelchairs/mobility scooter users, as they are not always easy to see.
# 3. Be aware that they may not have seen or heard you if you are approaching from behind.
# 4. Give way to pedestrians crossing or waiting to cross a road into which or from which you are turning.
# 5. If they have started to cross, they have priority, so give way.
# 6. Remain behind cyclists, horse riders, horse-drawn vehicles, and motorcyclists at junctions, even if they are waiting to turn and are positioned close to the kerb.
# 7. Watch out for long vehicles, which may be turning at a junction ahead; they may have to use the whole width of the road to make the turn.
# 8. Watch out for horse riders who may take a different line on the road from that which you would expect.
# 9. Do not assume, when waiting at a junction, that a vehicle coming from the right and signalling left will actually turn.
# 10. Wait and make sure.
# 11. Look all around before emerging.
# 12. Do not cross or join a road until there is a gap large enough for you to do so safely.
#
# ## Step 2: Extract relevant information for each sentence
#
# 1. Take extra care at junctions.
# - Subject: vehicle
# - Conclusion: take extra care
# - Deontic modality: should
# - Conditions: None
# - Syntactic structure:
#     - Conclusion:
#         - Subject: vehicle
#         - Deontic: should
#         - Verb: take extra care
#         - Complement: at junctions
#
# 2. Watch out for cyclists, motorcyclists, and pedestrians, including powered wheelchairs/mobility scooter users, as they are not always easy to see.
# - Subject: vehicle
# - Conclusion: watch out
# - Deontic modality: should
# - Conditions:
#     - cyclists, motorcyclists, and pedestrians are not always easy to see
# - Syntactic structure:
#     - Conclusion:
#         - Subject: vehicle
#         - Deontic: should
#         - Verb: watch out
#         - Complement: for cyclists, motorcyclists, and pedestrians
#     - Conditions:
#         - Subject: cyclists, motorcyclists, and pedestrians
#         - Verb: are
#         - Complement: not always easy to see
#
# 3. Be aware that they may not have seen or heard you if you are approaching from behind.
# - Subject: vehicle
# - Conclusion: be aware
# - Deontic modality: should
# - Conditions:
#     - they may not have seen or heard the vehicle
#     - the vehicle is approaching from behind
# - Syntactic structure:
#     - Conclusion:
#         - Subject: vehicle
#         - Deontic: should
#         - Verb: be aware
#         - Complement: None
#     - Conditions:
#         - Subject: they
#         - Verb: may not have seen or heard
#         - Complement: the vehicle
#         - Subject: vehicle
#         - Verb: is approaching
#         - Complement: from behind
#
# 4. Give way to pedestrians crossing or waiting to cross a road into which or from which you are turning.
# - Subject: vehicle
# - Conclusion: give way
# - Deontic modality: should
# - Conditions:
#     - pedestrians are crossing or waiting to cross
#     - the vehicle is turning into or from the road
# - Syntactic structure:
#     - Conclusion:
#         - Subject: vehicle
#         - Deontic: should
#         - Verb: give way
#         - Complement: to pedestrians
#     - Conditions:
#         - Subject: pedestrians
#         - Verb: are crossing or waiting to cross
#         - Complement: a road
#         - Subject: vehicle
#         - Verb: is turning
#         - Complement: into or from the road
#
# 5. If they have started to cross, they have priority, so give way.
# - Subject: vehicle
# - Conclusion: give way
# - Deontic modality: should
# - Conditions:
#     - pedestrians have started to cross
# - Syntactic structure:
#     - Conclusion:
#         - Subject: vehicle
#         - Deontic: should
#         - Verb: give way
#         - Complement: None
#     - Conditions:
#         - Subject: pedestrians
#         - Verb: have started to cross
#         - Complement: None
#
# 6. Remain behind cyclists, horse riders, horse-drawn vehicles, and motorcyclists at junctions, even if they are waiting to turn and are positioned close to the kerb.
# - Subject: vehicle
# - Conclusion: remain behind
# - Deontic modality: should
# - Conditions:
#     - cyclists, horse riders, horse-drawn vehicles, and motorcyclists are at junctions
#     - they are waiting to turn and are positioned close to the kerb
# - Syntactic structure:
#     - Conclusion:
#         - Subject: vehicle
#         - Deontic: should
#         - Verb: remain behind
#         - Complement: cyclists, horse riders, horse-drawn vehicles, and motorcyclists
#     - Conditions:
#         - Subject: cyclists, horse riders, horse-drawn vehicles, and motorcyclists
#         - Verb: are
#         - Complement: at junctions
#         - Subject: they
#         - Verb: are waiting to turn
#         - Complement: and are positioned close to the kerb
#
# 7. Watch out for long vehicles, which may be turning at a junction ahead; they may have to use the whole width of the road to make the turn.
# - Subject: vehicle
# - Conclusion: watch out
# - Deontic modality: should
# - Conditions:
#     - long vehicles may be turning at a junction ahead
#     - they may have to use the whole width of the road to make the turn
# - Syntactic structure:
#     - Conclusion:
#         - Subject: vehicle
#         - Deontic: should
#         - Verb: watch out
#         - Complement: for long vehicles
#     - Conditions:
#         - Subject: long vehicles
#         - Verb: may be turning
#         - Complement: at a junction ahead
#         - Subject: they
#         - Verb: may have to use
#         - Complement: the whole width of the road to make the turn
#
# 8. Watch out for horse riders who may take a different line on the road from that which you would expect.
# - Subject: vehicle
# - Conclusion: watch out
# - Deontic modality: should
# - Conditions:
#     - horse riders may take a different line on the road
# - Syntactic structure:
#     - Conclusion:
#         - Subject: vehicle
#         - Deontic: should
#         - Verb: watch out
#         - Complement: for horse riders
#     - Conditions:
#         - Subject: horse riders
#         - Verb: may take
#         - Complement: a different line on the road
#
# 9. Do not assume, when waiting at a junction, that a vehicle coming from the right and signalling left will actually turn.
# - Subject: vehicle
# - Conclusion: do not assume
# - Deontic modality: should not
# - Conditions:
#     - the vehicle is waiting at a junction
#     - a vehicle is coming from the right and signalling left
# - Syntactic structure:
#     - Conclusion:
#         - Subject: vehicle
#         - Deontic: should not
#         - Verb: assume
#         - Complement: None
#     - Conditions:
#         - Subject: vehicle
#         - Verb: is waiting
#         - Complement: at a junction
#         - Subject: a vehicle
#         - Verb: is coming from the right and signalling left
#         - Complement: None
#
# 10. Wait and make sure.
# - Subject: vehicle
# - Conclusion: wait and make sure
# - Deontic modality: should
# - Conditions: None
# - Syntactic structure:
#     - Conclusion:
#         - Subject: vehicle
#         - Deontic: should
#         - Verb: wait and make sure
#         - Complement: None
#
# 11. Look all around before emerging.
# - Subject: vehicle
# - Conclusion: look all around
# - Deontic modality: should
# - Conditions:
#     - before emerging
# - Syntactic structure:
#     - Conclusion:
#         - Subject: vehicle
#         - Deontic: should
#         - Verb: look all around
#         - Complement: None
#     - Conditions:
#         - Subject: None
#         - Verb: None
#         - Complement: before emerging
#
# 12. Do not cross or join a road until there is a gap large enough for you to do so safely.
# - Subject: vehicle
# - Conclusion: do not cross or join
# - Deontic modality: should not
# - Conditions:
#     - there is a gap large enough to cross or join safely
# - Syntactic structure:
#     - Conclusion:
#         - Subject: vehicle
#         - Deontic: should not
#         - Verb: cross or join
#         - Complement: a road
#     - Conditions:
#         - Subject: a gap
#         - Verb: is
#         - Complement: large enough to cross or join safely
#
# ## Step 3: Present the JSON
#
# ```json
# [
#     {
#         "source_text": "Take extra care at junctions.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "should",
#                 "verb": "take extra care",
#                 "complement": "at junctions"
#             },
#             "conditions": []
#         }
#     },
#     {
#         "source_text": "Watch out for cyclists, motorcyclists, and pedestrians, including powered wheelchairs/mobility scooter users, as they are not always easy to see.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "should",
#                 "verb": "watch out",
#                 "complement": "for cyclists, motorcyclists, and pedestrians"
#             },
#             "conditions": [
#                 {
#                     "subject": "cyclists, motorcyclists, and pedestrians",
#                     "verb": "are",
#                     "complement": "not always easy to see"
#                 }
#             ]
#         }
#     },
#     {
#         "source_text": "Be aware that they may not have seen or heard you if you are approaching from behind.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "should",
#                 "verb": "be aware",
#                 "complement": "None"
#             },
#             "conditions": [
#                 {
#                     "subject": "they",
#                     "verb": "may not have seen or heard",
#                     "complement": "the vehicle"
#                 },
#                 {
#                     "subject": "vehicle",
#                     "verb": "is approaching",
#                     "complement": "from behind"
#                 }
#             ]
#         }
#     },
#     {
#         "source_text": "Give way to pedestrians crossing or waiting to cross a road into which or from which you are turning.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "should",
#                 "verb": "give way",
#                 "complement": "to pedestrians"
#             },
#             "conditions": [
#                 {
#                     "subject": "pedestrians",
#                     "verb": "are crossing or waiting to cross",
#                     "complement": "a road"
#                 },
#                 {
#                     "subject": "vehicle",
#                     "verb": "is turning",
#                     "complement": "into or from the road"
#                 }
#             ]
#         }
#     },
#     {
#         "source_text": "If they have started to cross, they have priority, so give way.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "should",
#                 "verb": "give way",
#                 "complement": "None"
#             },
#             "conditions": [
#                 {
#                     "subject": "pedestrians",
#                     "verb": "have started to cross",
#                     "complement": "None"
#                 }
#             ]
#         }
#     },
#     {
#         "source_text": "Remain behind cyclists, horse riders, horse-drawn vehicles, and motorcyclists at junctions, even if they are waiting to turn and are positioned close to the kerb.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "should",
#                 "verb": "remain behind",
#                 "complement": "cyclists, horse riders, horse-drawn vehicles, and motorcyclists"
#             },
#             "conditions": [
#                 {
#                     "subject": "cyclists, horse riders, horse-drawn vehicles, and motorcyclists",
#                     "verb": "are",
#                     "complement": "at junctions"
#                 },
#                 {
#                     "subject": "they",
#                     "verb": "are waiting to turn",
#                     "complement": "and are positioned close to the kerb"
#                 }
#             ]
#         }
#     },
#     {
#         "source_text": "Watch out for long vehicles, which may be turning at a junction ahead; they may have to use the whole width of the road to make the turn.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "should",
#                 "verb": "watch out",
#                 "complement": "for long vehicles"
#             },
#             "conditions": [
#                 {
#                     "subject": "long vehicles",
#                     "verb": "may be turning",
#                     "complement": "at a junction ahead"
#                 },
#                 {
#                     "subject": "they",
#                     "verb": "may have to use",
#                     "complement": "the whole width of the road to make the turn"
#                 }
#             ]
#         }
#     },
#     {
#         "source_text": "Watch out for horse riders who may take a different line on the road from that which you would expect.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "should",
#                 "verb": "watch out",
#                 "complement": "for horse riders"
#             },
#             "conditions": [
#                 {
#                     "subject": "horse riders",
#                     "verb": "may take",
#                     "complement": "a different line on the road"
#                 }
#             ]
#         }
#     },
#     {
#         "source_text": "Do not assume, when waiting at a junction, that a vehicle coming from the right and signalling left will actually turn.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "should not",
#                 "verb": "assume",
#                 "complement": "None"
#             },
#             "conditions": [
#                 {
#                     "subject": "vehicle",
#                     "verb": "is waiting",
#                     "complement": "at a junction"
#                 },
#                 {
#                     "subject": "a vehicle",
#                     "verb": "is coming from the right and signalling left",
#                     "complement": "None"
#                 }
#             ]
#         }
#     },
#     {
#         "source_text": "Wait and make sure.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "should",
#                 "verb": "wait and make sure",
#                 "complement": "None"
#             },
#             "conditions": []
#         }
#     },
#     {
#         "source_text": "Look all around before emerging.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "should",
#                 "verb": "look all around",
#                 "complement": "None"
#             },
#             "conditions": [
#                 {
#                     "subject": "None",
#                     "verb": "None",
#                     "complement": "before emerging"
#                 }
#             ]
#         }
#     },
#     {
#         "source_text": "Do not cross or join a road until there is a gap large enough for you to do so safely.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "should not",
#                 "verb": "cross or join",
#                 "complement": "a road"
#             },
#             "conditions": [
#                 {
#                     "subject": "a gap",
#                     "verb": "is",
#                     "complement": "large enough to cross or join safely"
#                 }
#             ]
#         }
#     }
# ]
# ```
# =======
# 2025-07-11 15:05:46,015 - INFO - Validated output:
#
# ====
# [
#    {
#       "source_text": "Take extra care at junctions.",
#       "syntactic_structure": {
#          "conclusion": {
#             "subject": "vehicle",
#             "deontic": "should",
#             "verb": "take extra care",
#             "complement": "at junctions"
#          },
#          "conditions": []
#       }
#    },
#    {
#       "source_text": "Be aware that they may not have seen or heard you if you are approaching from behind.",
#       "syntactic_structure": {
#          "conclusion": {
#             "subject": "vehicle",
#             "deontic": "should",
#             "verb": "be aware",
#             "complement": "None"
#          },
#          "conditions": [
#             {
#                "subject": "they",
#                "verb": "may not have seen or heard",
#                "complement": "the vehicle"
#             },
#             {
#                "subject": "vehicle",
#                "verb": "is approaching",
#                "complement": "from behind"
#             }
#          ]
#       }
#    },
#    {
#       "source_text": "Give way to pedestrians crossing or waiting to cross a road into which or from which you are turning.",
#       "syntactic_structure": {
#          "conclusion": {
#             "subject": "vehicle",
#             "deontic": "should",
#             "verb": "give way",
#             "complement": "to pedestrians"
#          },
#          "conditions": [
#             {
#                "subject": "pedestrians",
#                "verb": "are crossing or waiting to cross",
#                "complement": "a road"
#             },
#             {
#                "subject": "vehicle",
#                "verb": "is turning",
#                "complement": "into or from the road"
#             }
#          ]
#       }
#    },
#    {
#       "source_text": "If they have started to cross, they have priority, so give way.",
#       "syntactic_structure": {
#          "conclusion": {
#             "subject": "vehicle",
#             "deontic": "should",
#             "verb": "give way",
#             "complement": "None"
#          },
#          "conditions": [
#             {
#                "subject": "pedestrians",
#                "verb": "have started to cross",
#                "complement": "None"
#             }
#          ]
#       }
#    },
#    {
#       "source_text": "Remain behind cyclists, horse riders, horse-drawn vehicles, and motorcyclists at junctions, even if they are waiting to turn and are positioned close to the kerb.",
#       "syntactic_structure": {
#          "conclusion": {
#             "subject": "vehicle",
#             "deontic": "should",
#             "verb": "remain behind",
#             "complement": "cyclists, horse riders, horse-drawn vehicles, and motorcyclists"
#          },
#          "conditions": [
#             {
#                "subject": "cyclists, horse riders, horse-drawn vehicles, and motorcyclists",
#                "verb": "are",
#                "complement": "at junctions"
#             },
#             {
#                "subject": "they",
#                "verb": "are waiting to turn",
#                "complement": "and are positioned close to the kerb"
#             }
#          ]
#       }
#    },
#    {
#       "source_text": "Do not assume, when waiting at a junction, that a vehicle coming from the right and signalling left will actually turn.",
#       "syntactic_structure": {
#          "conclusion": {
#             "subject": "vehicle",
#             "deontic": "should not",
#             "verb": "assume",
#             "complement": "None"
#          },
#          "conditions": [
#             {
#                "subject": "vehicle",
#                "verb": "is waiting",
#                "complement": "at a junction"
#             },
#             {
#                "subject": "a vehicle",
#                "verb": "is coming from the right and signalling left",
#                "complement": "None"
#             }
#          ]
#       }
#    },
#    {
#       "source_text": "Wait and make sure.",
#       "syntactic_structure": {
#          "conclusion": {
#             "subject": "vehicle",
#             "deontic": "should",
#             "verb": "wait and make sure",
#             "complement": "None"
#          },
#          "conditions": []
#       }
#    },
#    {
#       "source_text": "Look all around before emerging.",
#       "syntactic_structure": {
#          "conclusion": {
#             "subject": "vehicle",
#             "deontic": "should",
#             "verb": "look all around",
#             "complement": "None"
#          },
#          "conditions": [
#             {
#                "subject": "None",
#                "verb": "None",
#                "complement": "before emerging"
#             }
#          ]
#       }
#    },
#    {
#       "source_text": "Do not cross or join a road until there is a gap large enough for you to do so safely.",
#       "syntactic_structure": {
#          "conclusion": {
#             "subject": "vehicle",
#             "deontic": "should not",
#             "verb": "cross or join",
#             "complement": "a road"
#          },
#          "conditions": [
#             {
#                "subject": "a gap",
#                "verb": "is",
#                "complement": "large enough to cross or join safely"
#             }
#          ]
#       }
#    }
# ]
# =======
# 2025-07-11 15:05:46,016 - INFO - --------------------------------------------------
# 2025-07-11 15:05:46,016 - INFO - Processing: Rule 171
# 2025-07-11 15:05:46,016 - INFO - Source text:
# "You **MUST** stop behind the line at a junction with a ‘Stop’ sign and a solid white line across the road. Wait for a safe gap in the traffic before you move off.
#
# **Laws [RTA 1988 sect 36](http://www.legislation.gov.uk/ukpga/1988/52/section/36) & [TSRGD schedule 9 parts 7 and 8](https://www.legislation.gov.uk/uksi/2016/362/schedule/9/made)**"
# 2025-07-11 15:05:46,017 - INFO - --------------------------------------------------
# 2025-07-11 15:05:53,960 - INFO - Response:
#
# ====
# ## Step 1: Break the paragraph down into individual sentences and convert them to the singular tense
#
# 1. You **MUST** stop behind the line at a junction with a ‘Stop’ sign and a solid white line across the road.
# 2. Wait for a safe gap in the traffic before you move off.
#
# In singular tense:
# 1. A vehicle **MUST** stop behind the line at a junction with a ‘Stop’ sign and a solid white line across the road.
# 2. A vehicle waits for a safe gap in the traffic before it moves off.
#
# ## Step 2: For each sentence, extract the relevant information
#
# 1. A vehicle **MUST** stop behind the line at a junction with a ‘Stop’ sign and a solid white line across the road.
#
# - Subject: "vehicle"
# - Conclusion: "stop behind the line at a junction"
# - Deontic modality: "must"
# - Conditions:
#     * Singular: "the junction has a ‘Stop’ sign"
#     * Singular: "the junction has a solid white line across the road"
# - Syntactic structure (Singular tense):
#     Conclusion:
#         * Subject: "vehicle", Deontic: "must", Verb: "stop", Complement: "behind the line at a junction"
#     Conditions:
#         * Subject: "junction", Verb: "has", Complement: "a ‘Stop’ sign"
#         * Subject: "junction", Verb: "has", Complement: "a solid white line across the road"
#
# 2. A vehicle waits for a safe gap in the traffic before it moves off.
#
# - Subject: "vehicle"
# - Conclusion: "move off"
# - Deontic modality: "can" (assumed, as there's no explicit deontic operator)
# - Conditions:
#     * Singular: "there is a safe gap in the traffic"
# - Syntactic structure (Singular tense):
#     Conclusion:
#         * Subject: "vehicle", Deontic: "can", Verb: "move off", Complement: ""
#     Conditions:
#         * Subject: "a safe gap", Verb: "is", Complement: "in the traffic"
#
# ## Step 3: Present the JSON
#
# ```json
# [
#     {
#         "source_text": "You **MUST** stop behind the line at a junction with a ‘Stop’ sign and a solid white line across the road.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "must",
#                 "verb": "stop",
#                 "complement": "behind the line at a junction"
#             },
#             "conditions": [
#                 {
#                     "subject": "junction",
#                     "verb": "has",
#                     "complement": "a ‘Stop’ sign"
#                 },
#                 {
#                     "subject": "junction",
#                     "verb": "has",
#                     "complement": "a solid white line across the road"
#                 }
#             ]
#         }
#     },
#     {
#         "source_text": "Wait for a safe gap in the traffic before you move off.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "can",
#                 "verb": "move off",
#                 "complement": ""
#             },
#             "conditions": [
#                 {
#                     "subject": "a safe gap",
#                     "verb": "is",
#                     "complement": "in the traffic"
#                 }
#             ]
#         }
#     }
# ]
# ```
# =======
# 2025-07-11 15:05:53,961 - INFO - Validated output:
#
# ====
# [
#    {
#       "source_text": "You **MUST** stop behind the line at a junction with a \u2018Stop\u2019 sign and a solid white line across the road.",
#       "syntactic_structure": {
#          "conclusion": {
#             "subject": "vehicle",
#             "deontic": "must",
#             "verb": "stop",
#             "complement": "behind the line at a junction"
#          },
#          "conditions": [
#             {
#                "subject": "junction",
#                "verb": "has",
#                "complement": "a \u2018Stop\u2019 sign"
#             },
#             {
#                "subject": "junction",
#                "verb": "has",
#                "complement": "a solid white line across the road"
#             }
#          ]
#       }
#    },
#    {
#       "source_text": "Wait for a safe gap in the traffic before you move off.",
#       "syntactic_structure": {
#          "conclusion": {
#             "subject": "vehicle",
#             "deontic": "can",
#             "verb": "move off",
#             "complement": ""
#          },
#          "conditions": [
#             {
#                "subject": "a safe gap",
#                "verb": "is",
#                "complement": "in the traffic"
#             }
#          ]
#       }
#    }
# ]
# =======
# 2025-07-11 15:05:53,962 - INFO - --------------------------------------------------
# 2025-07-11 15:05:53,962 - INFO - Processing: Rule 172
# 2025-07-11 15:05:53,963 - INFO - Source text:
# "The approach to a junction may have a ‘Give Way’ sign or a triangle marked on the road. You **MUST** give way to traffic on the main road when emerging from a junction with broken white lines across the road.
#
# **Laws [RTA 1988 sect 36](http://www.legislation.gov.uk/ukpga/1988/52/section/36) & [TSRGD schedule 9 parts 7 and 8](https://www.legislation.gov.uk/uksi/2016/362/schedule/9/made)**"
# 2025-07-11 15:05:53,964 - INFO - --------------------------------------------------
# 2025-07-11 15:06:03,269 - INFO - Response:
#
# ====
# ## Step 1: Break the paragraph down into individual sentences and convert them to the singular tense
#
# 1. The approach to a junction may have a 'Give Way' sign or a triangle marked on the road.
# 2. You MUST give way to traffic on the main road when emerging from a junction with broken white lines across the road.
#
# ## Step 2: For each sentence, extract the relevant information
#
# 1. The approach to a junction may have a 'Give Way' sign or a triangle marked on the road.
#
# - Subject: "approach"
# - Conclusion: "have a 'Give Way' sign or a triangle marked on the road"
# - Deontic modality: "may"
# - Conditions: None
# - Syntactic structure (Singular tense):
#     Conclusion:
#         * Subject: "approach", Deontic: "may", Verb: "have", Complement: "a 'Give Way' sign or a triangle marked on the road"
#
# 2. You MUST give way to traffic on the main road when emerging from a junction with broken white lines across the road.
#
# - Subject: "vehicle"
# - Conclusion: "give way to traffic on the main road"
# - Deontic modality: "must"
# - Conditions:
#     * Singular: "the vehicle is emerging from a junction"
#     * Singular: "the junction has broken white lines across the road"
# - Syntactic structure (Singular tense):
#     Conclusion:
#         * Subject: "vehicle", Deontic: "must", Verb: "give way", Complement: "to traffic on the main road"
#     Conditions:
#         * Subject: "vehicle", Verb: "is emerging", Complement: "from a junction"
#         * Subject: "junction", Verb: "has", Complement: "broken white lines across the road"
#
# ## Step 3: Present the JSON
#
# ```json
# [
#     {
#         "source_text": "The approach to a junction may have a 'Give Way' sign or a triangle marked on the road.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "approach",
#                 "deontic": "may",
#                 "verb": "have",
#                 "complement": "a 'Give Way' sign or a triangle marked on the road"
#             },
#             "conditions": []
#         }
#     },
#     {
#         "source_text": "You MUST give way to traffic on the main road when emerging from a junction with broken white lines across the road.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "must",
#                 "verb": "give way",
#                 "complement": "to traffic on the main road"
#             },
#             "conditions": [
#                 {
#                     "subject": "vehicle",
#                     "verb": "is emerging",
#                     "complement": "from a junction"
#                 },
#                 {
#                     "subject": "junction",
#                     "verb": "has",
#                     "complement": "broken white lines across the road"
#                 }
#             ]
#         }
#     }
# ]
# ```
# =======
# 2025-07-11 15:06:03,270 - INFO - Validated output:
#
# ====
# [
#    {
#       "source_text": "You MUST give way to traffic on the main road when emerging from a junction with broken white lines across the road.",
#       "syntactic_structure": {
#          "conclusion": {
#             "subject": "vehicle",
#             "deontic": "must",
#             "verb": "give way",
#             "complement": "to traffic on the main road"
#          },
#          "conditions": [
#             {
#                "subject": "vehicle",
#                "verb": "is emerging",
#                "complement": "from a junction"
#             },
#             {
#                "subject": "junction",
#                "verb": "has",
#                "complement": "broken white lines across the road"
#             }
#          ]
#       }
#    }
# ]
# =======
# 2025-07-11 15:06:03,271 - INFO - --------------------------------------------------
# 2025-07-11 15:06:03,271 - INFO - Processing: Rule 173
# 2025-07-11 15:06:03,272 - INFO - Source text:
# "**Dual carriageways.** When crossing or turning right, first assess whether the central reservation is deep enough to protect the full length of your vehicle.
#
# *   If it is, then you should treat each half of the carriageway as a separate road. Wait in the central reservation until there is a safe gap in the traffic on the second half of the road.
# *   If the central reservation is too shallow for the length of your vehicle, wait until you can cross both carriageways in one go."
# 2025-07-11 15:06:03,272 - INFO - --------------------------------------------------
# 2025-07-11 15:06:15,428 - INFO - Response:
#
# ====
# ## Step 1: Break the paragraph down into individual sentences and convert them to the singular tense
#
# 1. When crossing or turning right, first assess whether the central reservation is deep enough to protect the full length of your vehicle.
# 2. If it is, then you should treat each half of the carriageway as a separate road.
# 3. Wait in the central reservation until there is a safe gap in the traffic on the second half of the road.
# 4. If the central reservation is too shallow for the length of your vehicle, wait until you can cross both carriageways in one go.
#
# ## Step 2: For each sentence, extract the relevant information
#
# 1. When crossing or turning right, first assess whether the central reservation is deep enough to protect the full length of your vehicle.
#
# - Subject: "vehicle"
# - Conclusion: "assess whether the central reservation is deep enough"
# - Deontic modality: "should" (implied, as it's a recommendation)
# - Conditions: None
# - Syntactic structure (Singular tense):
#     Conclusion:
#         * Subject: "vehicle", Deontic: "should", Verb: "assess", Complement: "whether the central reservation is deep enough"
#
# 2. If it is, then you should treat each half of the carriageway as a separate road.
#
# - Subject: "vehicle"
# - Conclusion: "treat each half of the carriageway as a separate road"
# - Deontic modality: "should"
# - Conditions:
#     * Singular: "the central reservation is deep enough for the vehicle"
# - Syntactic structure (Singular tense):
#     Conclusion:
#         * Subject: "vehicle", Deontic: "should", Verb: "treat", Complement: "each half of the carriageway as a separate road"
#     Conditions:
#         * Subject: "central reservation", Verb: "is", Complement: "deep enough for the vehicle"
#
# 3. Wait in the central reservation until there is a safe gap in the traffic on the second half of the road.
#
# - Subject: "vehicle"
# - Conclusion: "wait in the central reservation"
# - Deontic modality: None (implied "should" or "must" for safety, but using "can" as per instructions)
# - Conditions:
#     * Singular: "there is a safe gap in the traffic on the second half of the road"
# - Syntactic structure (Singular tense):
#     Conclusion:
#         * Subject: "vehicle", Deontic: "can", Verb: "wait", Complement: "in the central reservation"
#     Conditions:
#         * Subject: "a safe gap", Verb: "is", Complement: "in the traffic on the second half of the road"
#
# 4. If the central reservation is too shallow for the length of your vehicle, wait until you can cross both carriageways in one go.
#
# - Subject: "vehicle"
# - Conclusion: "wait until you can cross both carriageways"
# - Deontic modality: None (implied "should" or "must" for safety, but using "can" as per instructions)
# - Conditions:
#     * Singular: "the central reservation is too shallow for the vehicle"
#     * Singular: "you can cross both carriageways in one go"
# - Syntactic structure (Singular tense):
#     Conclusion:
#         * Subject: "vehicle", Deontic: "can", Verb: "wait", Complement: "until it can cross both carriageways"
#     Conditions:
#         * Subject: "central reservation", Verb: "is", Complement: "too shallow for the vehicle"
#         * Subject: "vehicle", Verb: "can", Complement: "cross both carriageways in one go"
#
# ## Step 3: Present the JSON
#
# ```json
# [
#     {
#         "source_text": "When crossing or turning right, first assess whether the central reservation is deep enough to protect the full length of your vehicle.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "should",
#                 "verb": "assess",
#                 "complement": "whether the central reservation is deep enough"
#             },
#             "conditions": []
#         }
#     },
#     {
#         "source_text": "If it is, then you should treat each half of the carriageway as a separate road.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "should",
#                 "verb": "treat",
#                 "complement": "each half of the carriageway as a separate road"
#             },
#             "conditions": [
#                 {
#                     "subject": "central reservation",
#                     "verb": "is",
#                     "complement": "deep enough for the vehicle"
#                 }
#             ]
#         }
#     },
#     {
#         "source_text": "Wait in the central reservation until there is a safe gap in the traffic on the second half of the road.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "can",
#                 "verb": "wait",
#                 "complement": "in the central reservation"
#             },
#             "conditions": [
#                 {
#                     "subject": "a safe gap",
#                     "verb": "is",
#                     "complement": "in the traffic on the second half of the road"
#                 }
#             ]
#         }
#     },
#     {
#         "source_text": "If the central reservation is too shallow for the length of your vehicle, wait until you can cross both carriageways in one go.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "can",
#                 "verb": "wait",
#                 "complement": "until it can cross both carriageways"
#             },
#             "conditions": [
#                 {
#                     "subject": "central reservation",
#                     "verb": "is",
#                     "complement": "too shallow for the vehicle"
#                 },
#                 {
#                     "subject": "vehicle",
#                     "verb": "can",
#                     "complement": "cross both carriageways in one go"
#                 }
#             ]
#         }
#     }
# ]
# ```
# =======
# 2025-07-11 15:06:15,429 - INFO - Validated output:
#
# ====
# [
#    {
#       "source_text": "When crossing or turning right, first assess whether the central reservation is deep enough to protect the full length of your vehicle.",
#       "syntactic_structure": {
#          "conclusion": {
#             "subject": "vehicle",
#             "deontic": "should",
#             "verb": "assess",
#             "complement": "whether the central reservation is deep enough"
#          },
#          "conditions": []
#       }
#    },
#    {
#       "source_text": "If it is, then you should treat each half of the carriageway as a separate road.",
#       "syntactic_structure": {
#          "conclusion": {
#             "subject": "vehicle",
#             "deontic": "should",
#             "verb": "treat",
#             "complement": "each half of the carriageway as a separate road"
#          },
#          "conditions": [
#             {
#                "subject": "central reservation",
#                "verb": "is",
#                "complement": "deep enough for the vehicle"
#             }
#          ]
#       }
#    },
#    {
#       "source_text": "Wait in the central reservation until there is a safe gap in the traffic on the second half of the road.",
#       "syntactic_structure": {
#          "conclusion": {
#             "subject": "vehicle",
#             "deontic": "can",
#             "verb": "wait",
#             "complement": "in the central reservation"
#          },
#          "conditions": [
#             {
#                "subject": "a safe gap",
#                "verb": "is",
#                "complement": "in the traffic on the second half of the road"
#             }
#          ]
#       }
#    },
#    {
#       "source_text": "If the central reservation is too shallow for the length of your vehicle, wait until you can cross both carriageways in one go.",
#       "syntactic_structure": {
#          "conclusion": {
#             "subject": "vehicle",
#             "deontic": "can",
#             "verb": "wait",
#             "complement": "until it can cross both carriageways"
#          },
#          "conditions": [
#             {
#                "subject": "central reservation",
#                "verb": "is",
#                "complement": "too shallow for the vehicle"
#             },
#             {
#                "subject": "vehicle",
#                "verb": "can",
#                "complement": "cross both carriageways in one go"
#             }
#          ]
#       }
#    }
# ]
# =======
# 2025-07-11 15:06:15,430 - INFO - --------------------------------------------------
# 2025-07-11 15:06:15,430 - INFO - Processing: Rule 174
# 2025-07-11 15:06:15,430 - INFO - Source text:
# "**Box junctions.** These have criss-cross yellow lines painted on the road (see ‘[Road markings](/guidance/the-highway-code/road-markings)’). You **MUST NOT** enter the box until your exit road or lane is clear. However, you may enter the box and wait when you want to turn right, and are only stopped from doing so by oncoming traffic, or by other vehicles waiting to turn right. At signalled roundabouts you **MUST NOT** enter the box unless you can cross over it completely without stopping.
#
# **Law [TSRGD schedule 9 parts 7 and 8](https://www.legislation.gov.uk/uksi/2016/362/schedule/9/made)**"
# 2025-07-11 15:06:15,431 - INFO - --------------------------------------------------
# 2025-07-11 15:06:28,868 - INFO - Response:
#
# ====
# ## Step 1: Break the paragraph down into individual sentences and convert them to the singular tense
#
# 1. These have criss-cross yellow lines painted on the road.
# 2. You MUST NOT enter the box until your exit road or lane is clear.
# 3. However, you may enter the box and wait when you want to turn right, and are only stopped from doing so by oncoming traffic, or by other vehicles waiting to turn right.
# 4. At signalled roundabouts you MUST NOT enter the box unless you can cross over it completely without stopping.
#
# ## Step 2: For each sentence, extract the relevant information
#
# 1. These have criss-cross yellow lines painted on the road.
# - Subject: "box junction"
# - Conclusion: "have criss-cross yellow lines painted on the road"
# - Deontic modality: None
# - Conditions: None
# - Syntactic structure (Singular tense):
#     * Conclusion:
#         + Subject: "box junction", Verb: "has", Complement: "criss-cross yellow lines painted on the road"
#
# 2. You MUST NOT enter the box until your exit road or lane is clear.
# - Subject: "vehicle"
# - Conclusion: "enter the box"
# - Deontic modality: "must not"
# - Conditions:
#     * Singular: "the exit road or lane is clear"
# - Syntactic structure (Singular tense):
#     * Conclusion:
#         + Subject: "vehicle", Deontic: "must not", Verb: "enter", Complement: "the box"
#     * Conditions:
#         + Subject: "exit road or lane", Verb: "is", Complement: "clear"
#
# 3. However, you may enter the box and wait when you want to turn right, and are only stopped from doing so by oncoming traffic, or by other vehicles waiting to turn right.
# - Subject: "vehicle"
# - Conclusion: "enter the box and wait"
# - Deontic modality: "may"
# - Conditions:
#     * Singular: "the vehicle wants to turn right"
#     * Singular: "the vehicle is stopped from doing so by oncoming traffic"
#     * Singular: "the vehicle is stopped from doing so by other vehicles waiting to turn right"
# - Syntactic structure (Singular tense):
#     * Conclusion:
#         + Subject: "vehicle", Deontic: "may", Verb: "enter and wait", Complement: "in the box"
#     * Conditions:
#         + Subject: "vehicle", Verb: "wants", Complement: "to turn right"
#         + Subject: "vehicle", Verb: "is stopped", Complement: "by oncoming traffic"
#         + Subject: "vehicle", Verb: "is stopped", Complement: "by other vehicles waiting to turn right"
#
# 4. At signalled roundabouts you MUST NOT enter the box unless you can cross over it completely without stopping.
# - Subject: "vehicle"
# - Conclusion: "enter the box"
# - Deontic modality: "must not"
# - Conditions:
#     * Singular: "the vehicle can cross over the box completely without stopping"
# - Syntactic structure (Singular tense):
#     * Conclusion:
#         + Subject: "vehicle", Deontic: "must not", Verb: "enter", Complement: "the box"
#     * Conditions:
#         + Subject: "vehicle", Verb: "can cross", Complement: "over the box completely without stopping"
#
# ## Step 3: Present the JSON
#
# ```json
# [
#     {
#         "source_text": "These have criss-cross yellow lines painted on the road.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "box junction",
#                 "deontic": null,
#                 "verb": "has",
#                 "complement": "criss-cross yellow lines painted on the road"
#             },
#             "conditions": []
#         }
#     },
#     {
#         "source_text": "You MUST NOT enter the box until your exit road or lane is clear.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "must not",
#                 "verb": "enter",
#                 "complement": "the box"
#             },
#             "conditions": [
#                 {
#                     "subject": "exit road or lane",
#                     "verb": "is",
#                     "complement": "clear"
#                 }
#             ]
#         }
#     },
#     {
#         "source_text": "However, you may enter the box and wait when you want to turn right, and are only stopped from doing so by oncoming traffic, or by other vehicles waiting to turn right.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "may",
#                 "verb": "enter and wait",
#                 "complement": "in the box"
#             },
#             "conditions": [
#                 {
#                     "subject": "vehicle",
#                     "verb": "wants",
#                     "complement": "to turn right"
#                 },
#                 {
#                     "subject": "vehicle",
#                     "verb": "is stopped",
#                     "complement": "by oncoming traffic"
#                 },
#                 {
#                     "subject": "vehicle",
#                     "verb": "is stopped",
#                     "complement": "by other vehicles waiting to turn right"
#                 }
#             ]
#         }
#     },
#     {
#         "source_text": "At signalled roundabouts you MUST NOT enter the box unless you can cross over it completely without stopping.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "must not",
#                 "verb": "enter",
#                 "complement": "the box"
#             },
#             "conditions": [
#                 {
#                     "subject": "vehicle",
#                     "verb": "can cross",
#                     "complement": "over the box completely without stopping"
#                 }
#             ]
#         }
#     }
# ]
# ```
# =======
# 2025-07-11 15:06:28,869 - INFO - Validated output:
#
# ====
# [
#    {
#       "source_text": "You MUST NOT enter the box until your exit road or lane is clear.",
#       "syntactic_structure": {
#          "conclusion": {
#             "subject": "vehicle",
#             "deontic": "must not",
#             "verb": "enter",
#             "complement": "the box"
#          },
#          "conditions": [
#             {
# ...
# 7. Road layout, markings or how the other vehicle is positioned can determine which course should be taken.
#
# ## Step 2: For each sentence, extract the relevant information
#
# 1. When turning right at a crossroad where an oncoming vehicle is also turning right, there is a choice of two methods.
# - Subject: "vehicle"
# - Conclusion: "turn right at a crossroad"
# - Deontic modality: None
# - Conditions:
#     * Singular: "the vehicle is turning right at a crossroad"
#     * Singular: "there is an oncoming vehicle also turning right"
# - Syntactic structure (Singular tense):
#     Conclusion:
#         * Subject: "vehicle", Deontic: "can", Verb: "turn right", Complement: "at a crossroad"
#     Conditions:
#         * Subject: "vehicle", Verb: "is", Complement: "turning right at a crossroad"
#         * Subject: "oncoming vehicle", Verb: "is", Complement: "also turning right"
#
# 2. Turn right side to right side; keep the other vehicle on your right and turn behind it.
# - Subject: "vehicle"
# - Conclusion: "turn right side to right side"
# - Deontic modality: None
# - Conditions:
#     * Singular: "the other vehicle is on the right"
# - Syntactic structure (Singular tense):
#     Conclusion:
#         * Subject: "vehicle", Deontic: "can", Verb: "turn", Complement: "right side to right side"
#     Conditions:
#         * Subject: "other vehicle", Verb: "is", Complement: "on the right"
#
# 3. This is generally the safer method as you have a clear view of any approaching traffic when completing your turn.
# - Subject: "vehicle"
# - Conclusion: "have a clear view of approaching traffic"
# - Deontic modality: None
# - Conditions:
#     * Singular: "the vehicle is completing its turn"
# - Syntactic structure (Singular tense):
#     Conclusion:
#         * Subject: "vehicle", Deontic: "can", Verb: "have", Complement: "a clear view of approaching traffic"
#     Conditions:
#         * Subject: "vehicle", Verb: "is", Complement: "completing its turn"
#
# 4. Turn left side to left side, turning in front of each other.
# - Subject: "vehicle"
# - Conclusion: "turn left side to left side"
# - Deontic modality: None
# - Conditions: None
# - Syntactic structure (Singular tense):
#     Conclusion:
#         * Subject: "vehicle", Deontic: "can", Verb: "turn", Complement: "left side to left side"
#     Conditions: []
#
# 5. This can block your view of oncoming vehicles, so take extra care.
# - Subject: "vehicle"
# - Conclusion: "block the view of oncoming vehicles"
# - Deontic modality: None
# - Conditions: None
# - Syntactic structure (Singular tense):
#     Conclusion:
#         * Subject: "vehicle", Deontic: "can", Verb: "block", Complement: "the view of oncoming vehicles"
#     Conditions: []
#
# 6. Cyclists and motorcyclists in particular may be hidden from your view.
# - Subject: "cyclists and motorcyclists"
# - Conclusion: "be hidden from the view"
# - Deontic modality: None
# - Conditions: None
# - Syntactic structure (Singular tense):
#     Conclusion:
#         * Subject: "cyclist or motorcyclist", Deontic: "can", Verb: "be", Complement: "hidden from the view"
#     Conditions: []
#
# 7. Road layout, markings or how the other vehicle is positioned can determine which course should be taken.
# - Subject: "road layout, markings or the other vehicle"
# - Conclusion: "determine the course to be taken"
# - Deontic modality: None
# - Conditions: None
# - Syntactic structure (Singular tense):
#     Conclusion:
#         * Subject: "road layout, marking or other vehicle", Deontic: "can", Verb: "determine", Complement: "the course to be taken"
#     Conditions: []
#
# ## Step 3: Present the JSON
#
# ```json
# [
#     {
#         "source_text": "When turning right at a crossroad where an oncoming vehicle is also turning right, there is a choice of two methods.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "can",
#                 "verb": "turn right",
#                 "complement": "at a crossroad"
#             },
#             "conditions": [
#                 {
#                     "subject": "vehicle",
#                     "verb": "is",
#                     "complement": "turning right at a crossroad"
#                 },
#                 {
#                     "subject": "oncoming vehicle",
#                     "verb": "is",
#                     "complement": "also turning right"
#                 }
#             ]
#         }
#     },
#     {
#         "source_text": "Turn right side to right side; keep the other vehicle on your right and turn behind it.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "can",
#                 "verb": "turn",
#                 "complement": "right side to right side"
#             },
#             "conditions": [
#                 {
#                     "subject": "other vehicle",
#                     "verb": "is",
#                     "complement": "on the right"
#                 }
#             ]
#         }
#     },
#     {
#         "source_text": "This is generally the safer method as you have a clear view of any approaching traffic when completing your turn.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "can",
#                 "verb": "have",
#                 "complement": "a clear view of approaching traffic"
#             },
#             "conditions": [
#                 {
#                     "subject": "vehicle",
#                     "verb": "is",
#                     "complement": "completing its turn"
#                 }
#             ]
#         }
#     },
#     {
#         "source_text": "Turn left side to left side, turning in front of each other.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "can",
#                 "verb": "turn",
#                 "complement": "left side to left side"
#             },
#             "conditions": []
#         }
#     },
#     {
#         "source_text": "This can block your view of oncoming vehicles, so take extra care.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "can",
#                 "verb": "block",
#                 "complement": "the view of oncoming vehicles"
#             },
#             "conditions": []
#         }
#     },
#     {
#         "source_text": "Cyclists and motorcyclists in particular may be hidden from your view.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "cyclist or motorcyclist",
#                 "deontic": "can",
#                 "verb": "be",
#                 "complement": "hidden from the view"
#             },
#             "conditions": []
#         }
#     },
#     {
#         "source_text": "Road layout, markings or how the other vehicle is positioned can determine which course should be taken.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "road layout, marking or other vehicle",
#                 "deontic": "can",
#                 "verb": "determine",
#                 "complement": "the course to be taken"
#             },
#             "conditions": []
#         }
#     }
# ]
# ```
# =======
# 2025-07-11 15:07:47,050 - INFO - Validated output:
#
# ====
# [
#    {
#       "source_text": "When turning right at a crossroad where an oncoming vehicle is also turning right, there is a choice of two methods.",
#       "syntactic_structure": {
#          "conclusion": {
#             "subject": "vehicle",
#             "deontic": "can",
#             "verb": "turn right",
#             "complement": "at a crossroad"
#          },
#          "conditions": [
#             {
#                "subject": "vehicle",
#                "verb": "is",
#                "complement": "turning right at a crossroad"
#             },
#             {
#                "subject": "oncoming vehicle",
#                "verb": "is",
#                "complement": "also turning right"
#             }
#          ]
#       }
#    },
#    {
#       "source_text": "Turn right side to right side; keep the other vehicle on your right and turn behind it.",
#       "syntactic_structure": {
#          "conclusion": {
#             "subject": "vehicle",
#             "deontic": "can",
#             "verb": "turn",
#             "complement": "right side to right side"
#          },
#          "conditions": [
#             {
#                "subject": "other vehicle",
#                "verb": "is",
#                "complement": "on the right"
#             }
#          ]
#       }
#    },
#    {
#       "source_text": "This is generally the safer method as you have a clear view of any approaching traffic when completing your turn.",
#       "syntactic_structure": {
#          "conclusion": {
#             "subject": "vehicle",
#             "deontic": "can",
#             "verb": "have",
#             "complement": "a clear view of approaching traffic"
#          },
#          "conditions": [
#             {
#                "subject": "vehicle",
#                "verb": "is",
#                "complement": "completing its turn"
#             }
#          ]
#       }
#    },
#    {
#       "source_text": "Turn left side to left side, turning in front of each other.",
#       "syntactic_structure": {
#          "conclusion": {
#             "subject": "vehicle",
#             "deontic": "can",
#             "verb": "turn",
#             "complement": "left side to left side"
#          },
#          "conditions": []
#       }
#    },
#    {
#       "source_text": "This can block your view of oncoming vehicles, so take extra care.",
#       "syntactic_structure": {
#          "conclusion": {
#             "subject": "vehicle",
#             "deontic": "can",
#             "verb": "block",
#             "complement": "the view of oncoming vehicles"
#          },
#          "conditions": []
#       }
#    }
# ]
# =======
# 2025-07-11 15:07:47,050 - INFO - --------------------------------------------------
# 2025-07-11 15:07:47,051 - INFO - Processing: Rule 182
# 2025-07-11 15:07:47,051 - INFO - Source text:
# "Use your mirrors and give a left-turn signal well before you turn left. Do not overtake just before you turn left and watch out for traffic coming up on your left before you make the turn, especially if driving a large vehicle. Cyclists, motorcyclists and other road users in particular may be hidden from your view."
# 2025-07-11 15:07:47,051 - INFO - --------------------------------------------------
# 2025-07-11 15:07:54,618 - INFO - Response:
#
# ====
# ## Step 1: Break the paragraph down into individual sentences and convert them to the singular tense
#
# 1. Use your mirror and give a left-turn signal well before you turn left.
# 2. Do not overtake just before you turn left and watch out for traffic coming up on your left before you make the turn, especially if driving a large vehicle.
# 3. Cyclists, motorcyclists and other road users in particular may be hidden from your view.
#
# ## Step 2: For each sentence, extract the relevant information
#
# 1. Use your mirror and give a left-turn signal well before you turn left.
#
# - Subject: "vehicle"
# - Conclusion: "give a left-turn signal"
# - Deontic modality: "should" (assumed, as it's a recommendation)
# - Conditions:
#     * Singular: "the vehicle is turning left"
# - Syntactic structure (Singular tense):
#     Conclusion:
#         * Subject: "vehicle", Deontic: "should", Verb: "give", Complement: "a left-turn signal"
#     Conditions:
#         * Subject: "vehicle", Verb: "is", Complement: "turning left"
#
# 2. Do not overtake just before you turn left and watch out for traffic coming up on your left before you make the turn, especially if driving a large vehicle.
#
# - Subject: "vehicle"
# - Conclusion 1: "not overtake"
# - Deontic modality 1: "must not"
# - Conclusion 2: "watch out for traffic"
# - Deontic modality 2: "should" (assumed, as it's a recommendation)
# - Conditions:
#     * Singular: "the vehicle is turning left"
#     * Singular: "the vehicle is driving a large vehicle" (optional)
# - Syntactic structure (Singular tense):
#     Conclusion 1:
#         * Subject: "vehicle", Deontic: "must not", Verb: "overtake", Complement: ""
#     Conclusion 2:
#         * Subject: "vehicle", Deontic: "should", Verb: "watch out", Complement: "for traffic"
#     Conditions:
#         * Subject: "vehicle", Verb: "is", Complement: "turning left"
#         * Subject: "vehicle", Verb: "is", Complement: "driving a large vehicle"
#
# 3. Cyclists, motorcyclists and other road users in particular may be hidden from your view.
#
# - Subject: "cyclists, motorcyclists and other road users"
# - Conclusion: None
# - Deontic modality: None
# - Conditions:
#     * Singular: "the vehicle is turning left"
# - Syntactic structure (Singular tense):
#     Conclusion: None
#     Conditions:
#         * Subject: "cyclist, motorcyclist or other road user", Verb: "may be", Complement: "hidden from the vehicle's view"
#
# ## Step 3: Present the JSON
#
# ```json
# [
#     {
#         "source_text": "Use your mirror and give a left-turn signal well before you turn left.",
#         "syntactic_structure": {
#             "conclusion": {
#                 "subject": "vehicle",
#                 "deontic": "should",
#                 "verb": "give",
#                 "complement": "a left-turn signal"
#             },
#             "conditions": [
#                 {
#                     "subject": "vehicle",
#                     "verb": "is",
#                     "complement": "turning left"
#                 }
#             ]
#         }
#     },
#     {
#         "source_text": "Do not overtake just before you turn left and watch out for traffic coming up on your left before you make the turn, especially if driving a large vehicle.",
#         "syntactic_structure": {
#             "conclusion": [
#                 {
#                     "subject": "vehicle",
#                     "deontic": "must not",
#                     "verb": "overtake",
#                     "complement": ""
#                 },
#                 {
#                     "subject": "vehicle",
#                     "deontic": "should",
#                     "verb": "watch out",
#                     "complement": "for traffic"
#                 }
#             ],
#             "conditions": [
#                 {
#                     "subject": "vehicle",
#                     "verb": "is",
#                     "complement": "turning left"
#                 },
#                 {
#                     "subject": "vehicle",
#                     "verb": "is",
#                     "complement": "driving a large vehicle"
#                 }
#             ]
#         }
#     },
#     {
#         "source_text": "Cyclists, motorcyclists and other road users in particular may be hidden from your view.",
#         "syntactic_structure": {
#             "conclusion": null,
#             "conditions": [
#                 {
#                     "subject": "cyclist, motorcyclist or other road user",
#                     "verb": "may be",
#                     "complement": "hidden from the vehicle's view"
#                 }
#             ]
#         }
#     }
# ]
# ```
# =======
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 10
#       7 logging.info(f"Source text: \n\"{source_text}\"")
#       8 logging.info("-" * 50)
# ---> 10 content = extract_json_le(
#      11     source_text=source_text,
#      12     previous_le=existing_logical_english
#      13 )
#
# Cell In[5], line 141, in extract_json_le(source_text, previous_le)
#     137 logging.info(f"Response: \n\n====\n{response}\n=======")
#     139 json_structure = extract_json_from_markdown(response)
# --> 141 valid_json_content = filter_content(json_structure)
#     143 logging.info(f"Validated output: \n\n====\n{json.dumps(valid_json_content, indent=3)}\n=======")
#
# Cell In[5], line 91, in filter_content(data)
#      87 if not conclusion:
#      88     continue
#      90 is_conclusion_valid = all([
# ---> 91     conclusion.get("subject") == "vehicle",
#      92     conclusion.get("deontic"),
#      93     conclusion.get("verb"),
#      94     conclusion.get("verb") != "watch out"
#      95 ])
#      97 if not is_conclusion_valid:
#      98     continue
#
# AttributeError: 'list' object has no attribute 'get'
